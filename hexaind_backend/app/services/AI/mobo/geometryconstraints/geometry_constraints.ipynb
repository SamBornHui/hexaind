# %% [markdown]
# BCED

# %%
gc_payload = {'mobo_id': 'prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW',
 'mobo_name': 'BCED_ABANDONED_TRIALS',
 'project_id': '657849cebb20a16a3466db93',
 'user_id': '657849a6bb20a16a3466db92',
 'constraints_folder': 'tests/BCED_CUSTOM',
 'next_observations':{21: {'t_0': 43.611882934143125, 't_1': 12.336516038553336, 't_2': -36.98860123071595, 't_3': 39.65314793415599, 't_4': -0.7946568398304898, 't_5': -68.3742718357108, 't_6': -82.43569115616742, 't_7': 1.056466265008173, 't_8': 39.145815432615215, 't_9': -0.2127822791143732, 'r_1': 2.7206017520617998, 'r_2': 4.647071991100516, 'r_3': 1.9501754041833617, 'r_4': 173.3077550965962, 'r_5': 0.25343541248355017, 'r_6': 0.7334202543353905, 'r_7': 31.768778319343195, 'r_8': 0.6836910673578451, 'r_9': 74.7041991807273, 'r_10': 0.529221507260381}, 22: {'t_0': 43.61187598184618, 't_1': 12.336517875125704, 't_2': -36.988595336737646, 't_3': 39.65314183648995, 't_4': -0.7946658369564576, 't_5': -68.37428697509503, 't_6': -82.43572013767127, 't_7': 1.0564813545483673, 't_8': 39.145842589199276, 't_9': -0.21278573391655708, 'r_1': 2.7206019420119447, 'r_2': 4.647070893682213, 'r_3': 1.9501749181772554, 'r_4': 173.30765640448325, 'r_5': 0.25343543034891725, 'r_6': 0.7334200695087065, 'r_7': 31.76878898974908, 'r_8': 0.683691270773092, 'r_9': 74.7042108981799, 'r_10': 0.5292217906538281}, 23: {'t_0': 43.61527900331481, 't_1': 12.336263387955556, 't_2': -36.98502355293037, 't_3': 39.64783425846974, 't_4': -0.8000434385347268, 't_5': -68.37978273598182, 't_6': -82.44118481774092, 't_7': 1.063290160062893, 't_8': 39.157158732801946, 't_9': -0.21594959738474362, 'r_1': 2.7212348385698237, 'r_2': 4.648434754364935, 'r_3': 1.9504188803173197, 'r_4': 173.33624757394364, 'r_5': 0.25343491722883016, 'r_6': 0.7334008935650768, 'r_7': 31.776540808378698, 'r_8': 0.6836387816224243, 'r_9': 74.73293265338326, 'r_10': 0.5293523924055709}}
}
gc_payload
# Out:
# {'mobo_id': 'prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW',
#  'mobo_name': 'BCED_ABANDONED_TRIALS',
#  'project_id': '657849cebb20a16a3466db93',
#  'user_id': '657849a6bb20a16a3466db92',
#  'constraints_folder': 'tests/BCED_CUSTOM',
#  'next_observations': {21: {'t_0': 43.611882934143125,
#    't_1': 12.336516038553336,
#    't_2': -36.98860123071595,
#    't_3': 39.65314793415599,
#    't_4': -0.7946568398304898,
#    't_5': -68.3742718357108,
#    't_6': -82.43569115616742,
#    't_7': 1.056466265008173,
#    't_8': 39.145815432615215,
#    't_9': -0.2127822791143732,
#    'r_1': 2.7206017520617998,
#    'r_2': 4.647071991100516,
#    'r_3': 1.9501754041833617,
#    'r_4': 173.3077550965962,
#    'r_5': 0.25343541248355017,
#    'r_6': 0.7334202543353905,
#    'r_7': 31.768778319343195,
#    'r_8': 0.6836910673578451,
#    'r_9': 74.7041991807273,
#    'r_10': 0.529221507260381},
#   22: {'t_0': 43.61187598184618,
#    't_1': 12.336517875125704,
#    't_2': -36.988595336737646,
# ...

# %% [markdown]
# AICED

# %%
gc_payload = {'mobo_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123',
 'mobo_name': 'AICED_CUST',
 'project_id': '657849cebb20a16a3466db93',
 'user_id': '657849a6bb20a16a3466db92',
 'constraints_folder': 'tests/AICED_CUSTOM',
 'next_observations':{30: {'dcp_spacer': 0.18, 'pp_spacer': 0.144, 'ips_pressure': 94.50111880239174, 'up_pressure': 60.0, 'friction_coeff': 0.05, 'upper_radius': 0.11238156856611926, 'lower_radius': 0.005101214, 't_value': 0.010755824, 'lr_opening': 1.679, 'catcher_depth': 0.08841220778630417, 'ips_radius': 0.6031956914195314, 'dcr_radius': 0.20603130721094384, 'dcp_radius_1': 0.26518600578740953, 'dcp_radius_2': 0.6961713695440761}, 31: {'dcp_spacer': 0.18, 'pp_spacer': 0.144, 'ips_pressure': 94.50094338756699, 'up_pressure': 60.0, 'friction_coeff': 0.05, 'upper_radius': 0.11240133525702886, 'lower_radius': 0.005101214, 't_value': 0.010755824, 'lr_opening': 1.679, 'catcher_depth': 0.08842604411612918, 'ips_radius': 0.6029451089035301, 'dcr_radius': 0.2060772934083707, 'dcp_radius_1': 0.26517618419701755, 'dcp_radius_2': 0.696077261114768}} 
 }
gc_payload
# Out:
# {'mobo_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123',
#  'mobo_name': 'AICED_CUST',
#  'project_id': '657849cebb20a16a3466db93',
#  'user_id': '657849a6bb20a16a3466db92',
#  'constraints_folder': 'tests/AICED_CUSTOM',
#  'next_observations': {30: {'dcp_spacer': 0.18,
#    'pp_spacer': 0.144,
#    'ips_pressure': 94.50111880239174,
#    'up_pressure': 60.0,
#    'friction_coeff': 0.05,
#    'upper_radius': 0.11238156856611926,
#    'lower_radius': 0.005101214,
#    't_value': 0.010755824,
#    'lr_opening': 1.679,
#    'catcher_depth': 0.08841220778630417,
#    'ips_radius': 0.6031956914195314,
#    'dcr_radius': 0.20603130721094384,
#    'dcp_radius_1': 0.26518600578740953,
#    'dcp_radius_2': 0.6961713695440761},
#   31: {'dcp_spacer': 0.18,
#    'pp_spacer': 0.144,
#    'ips_pressure': 94.50094338756699,
#    'up_pressure': 60.0,
#    'friction_coeff': 0.05,
#    'upper_radius': 0.11240133525702886,
#    'lower_radius': 0.005101214,
#    't_value': 0.010755824,
# ...

# %%
import sys
sys.path.append('../../../../')
from service import GCService
from pymongo import MongoClient
db_config = dict(db_address = '192.168.0.66' + ':27017', db_name = "Databrick", db_username = "Databrick", db_password = "test")
client = MongoClient(db_config['db_address'],
                        username=db_config['db_username'],
                        password=db_config['db_password'],
                        authSource=db_config['db_name'])

gc = GCService(db_sync_client=client)
aa = gc.run_gc(gc_payload)

# %%
aa
# Out:
# {30: {'dcp_spacer': 0.18,
#   'pp_spacer': 0.144,
#   'ips_pressure': 94.50111880239174,
#   'up_pressure': 60.0,
#   'friction_coeff': 0.05,
#   'upper_radius': 0.11238156856611926,
#   'lower_radius': 0.005101214,
#   't_value': 0.010755824,
#   'lr_opening': 1.679,
#   'catcher_depth': 0.08841220778630417,
#   'ips_radius': 0.6031956914195314,
#   'dcr_radius': 0.20603130721094384,
#   'dcp_radius_1': 0.26518600578740953,
#   'dcp_radius_2': 0.6961713695440761,
#   'iter_csv_path': '/tmp/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123/batch_30/trial_30/param_values.csv',
#   'fail_flag': 1,
#   'rescale_files': []},
#  31: {'dcp_spacer': 0.18,
#   'pp_spacer': 0.144,
#   'ips_pressure': 94.50094338756699,
#   'up_pressure': 60.0,
#   'friction_coeff': 0.05,
#   'upper_radius': 0.11240133525702886,
#   'lower_radius': 0.005101214,
#   't_value': 0.010755824,
#   'lr_opening': 1.679,
#   'catcher_depth': 0.08842604411612918,
# ...

# %%
type(aa)==dict
# Out:
# True

# %%
bb = aa[30]

# %%
bb.get('iter_csv_path', None)
# Out:
# '/tmp/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123/batch_30/trial_30/param_values.csv'

# %% [markdown]
# modules

# %%
import sys
sys.path.append('../../../../../')
from app.services.data.assets.modules.service import *
from pymongo import MongoClient
db_config = dict(db_address = '0.0.0.0' + ':27017', db_name = "Databrick", db_username = "Databrick", db_password = "test")
client = MongoClient(db_config['db_address'],
                        username=db_config['db_username'],
                        password=db_config['db_password'],
                        authSource=db_config['db_name'])

# %%
# BCED_Validation  = '65a15ddecbe8ff10ec0dcd53'
# AICED_Validation = '65a164decbe8ff10ec0dcd55'

# %%
from pathlib import Path
import zipfile
import sys

ms = ModuleService(db_sync_client=client)
modules_info = ms.get_module_record_by_id(module_id='65a15ddecbe8ff10ec0dcd53')

module_path = modules_info.module_location.path
if modules_info.module_location.extension == 'ZIP':
    print('zip block')
    modules_dir = os.path.dirname(modules_info.module_location.path)
    modules_dir = Path(modules_dir)
    if not (modules_dir/'custom_driver.py').is_file():
        print('going to extract zip file')
        with zipfile.ZipFile(modules_info.module_location.path, 'r') as zip_ref:
            # Extract all contents to the specified directory
            zip_ref.extractall(modules_dir)
    else:
        print('zip already extracted')
        pass

    sys.path.append(str(modules_dir))
    module_path = str(modules_dir/'custom_driver.py')

cust_modules = ms.import_module_from_path(module_name='custom_driver', module_path=module_path)

cust_modules
# Out:
# zip block
# zip already extracted
# <module 'custom_driver' from '/tmp/hexaind-data/modules/4e5d69bd-9505-464c-a733-30de0d1ffce5/custom_driver.py'>

# %%
param_file = '/tmp/hexaind-data/hexaind-datasets/mobo_experiments/prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW/batch_21/trial_21/param_values.csv'
cust_modules.PreProcess(Path(param_file))
# Out:
# before createFormingDataFile
# before intializePaths
# after intializePaths
# ...

# %%
ms = ModuleService(db_sync_client=client)
modules_info = ms.get_module_record_by_id(module_id='659fd13567aa779ce80b9e77')
modules_info
# Out:
# Module(id='659fd13567aa779ce80b9e77', version='1.0', user_id='', project_id='456', site_id='123', action_id='', name='custom_driver', description='custom_driver file for AICED', module_type=<ModuleType.PYTHON: 'PYTHON'>, upload_status=<UploadStatus.COMPLETED: 'COMPLETED'>, upload_stats=UploadStats(percentage='100%'), metadata={}, created_at=datetime.datetime(2024, 1, 11, 16, 29, 57), module_location=ModuleLocation(extension=<ModuleExtenstion.PY: 'PY'>, path='/tmp/modules/37482e90-b246-43e5-b820-021cbad1a0ad.py'), access_mode=<AccessMode.EXTERNAL: 'EXTERNAL'>, tags=[])

# %%
cust_modules = ms.import_module_from_path(module_name=modules_info.name, module_path=modules_info.module_location.path)
cust_modules
# Out:
# <module 'custom_driver' from '/tmp/modules/37482e90-b246-43e5-b820-021cbad1a0ad.py'>

# %%
cust_modules.PreProcess()

# %% [markdown]
# BCED

# %%
bced_modules_info = ms.get_module_record_by_id(module_id='659ff9fb3de73cc58b737ece')
bced_modules_info
# Out:
# Module(id='659ff9fb3de73cc58b737ece', version='1.0', user_id='', project_id='456', site_id='123', action_id='', name='custom_driver_bced_validation', description='custom_driver_bced_validation', module_type=<ModuleType.PYTHON: 'PYTHON'>, upload_status=<UploadStatus.COMPLETED: 'COMPLETED'>, upload_stats=UploadStats(percentage='100%'), metadata={}, created_at=datetime.datetime(2024, 1, 11, 19, 23, 55, 676000), module_location=ModuleLocation(extension=<ModuleExtenstion.ZIP: 'ZIP'>, path='/tmp/modules/44a814aa-e433-477b-84a4-333c501f0c72/44a814aa-e433-477b-84a4-333c501f0c72.zip'), access_mode=<AccessMode.EXTERNAL: 'EXTERNAL'>, tags=[])

# %%
from pathlib import Path
modules_dir = os.path.dirname(bced_modules_info.module_location.path)
modules_dir = Path(modules_dir)
modules_dir
# Out:
# PosixPath('/tmp/modules/44a814aa-e433-477b-84a4-333c501f0c72')

# %%
(modules_dir/'custom_driver.py').is_file()
# Out:
# True

# %%
import zipfile
import sys
if bced_modules_info.module_location.extension == 'ZIP':
    print('zip block')
    if not (modules_dir/'custom_driver.py').is_file():
        print('going to extract zip file')
        with zipfile.ZipFile(bced_modules_info.module_location.path, 'r') as zip_ref:
            # Extract all contents to the specified directory
            zip_ref.extractall(modules_dir)
    else:
        print('zip already extracted')

    sys.path.append(str(modules_dir))
    cust_modules = ms.import_module_from_path(module_name='custom_driver', module_path=str(modules_dir/'custom_driver.py'))

elif bced_modules_info.module_location.extension == 'PY':
    cust_modules = ms.import_module_from_path(module_name='custom_driver', module_path=modules_info.module_location.path)
# Out:
# zip block
# zip already extracted

# %%
cust_modules
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__fspath__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__truediv__',
#  '_cached_cparts',
#  '_cparts',
#  '_drv',
#  '_flavour',
#  '_format_parsed_parts',
#  '_from_parsed_parts',
#  '_from_parts',
#  '_hash',
#  '_make_child',
#  '_make_child_relpath',
#  '_parse_args',
#  '_parts',
#  '_pparts',
#  '_root',
#  '_scandir',
#  '_str',
#  'absolute',
#  'anchor',
#  'as_posix',
#  'as_uri',
#  'chmod',
#  'cwd',
#  'drive',
#  'exists',
#  'expanduser',
#  'glob',
#  'group',
#  'hardlink_to',
#  'home',
#  'is_absolute',
# ...

# %%
import zipfile

# Specify the path to your ZIP file
zip_file_path = 'path/to/your/file.zip'

# Specify the directory where you want to extract the contents
extract_dir = 'path/to/extract'

# Open the ZIP file in read mode
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all contents to the specified directory
    zip_ref.extractall(extract_dir)

print("ZIP file extracted successfully.")
