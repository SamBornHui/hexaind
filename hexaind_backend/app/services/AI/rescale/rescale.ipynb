# %%
######### step 1 #######


from pymongo import MongoClient
db_config = dict(db_address = '0.0.0.0' + ':27017', db_name = "Hexaind", db_username = "", db_password = "")
client = MongoClient(db_config['db_address'],
                        username=db_config['db_username'],
                        password=db_config['db_password'],
                        authSource=db_config['db_name'])
db = client['Hexaind']

# %%
########## step 2 ########
# ingest connector data 
## ingest data into db and pass id in payload as 'rescale_connector_id'
# note run only first time other skip these steps  

######### step 1 #######


from bson import ObjectId
import datetime

rescale_data = {'_id': ObjectId('659d5ec5dc18e4cfbd266399'),
 'id': '',
 'name': 'azure-dev',
 'description': 'Connector Description',
 'type': 'RESCALE',
 'configuration': {'token': 'd5a621e0819eebdd14d6394af40660cab4a3d653',

  'rescale_settings': ''},
 'owner_id': '',
 'owner_name': '',
 'created_at': datetime.datetime(2024, 1, 16, 15, 10, 25, 532000),
 'last_modified_by_id': '',
 'last_modified_at': datetime.datetime(2024, 1, 16, 15, 10, 25, 532000),
 'project_id': '1',
 'site_id': '1',
 'version': '1.0'}



db.connectors.insert_one(rescale_data)

# %%
########## step 3 ########
# select for real job


rescale_config = {'software_type': 'Abaqus',
 'analysis_type': 'AI Can End ',
 'files': [{'id': 'jRwGJh', 'file_name': 'MG_Buckling.py'},
    {'id': 'PdDUxh', 'file_name': 'MG_Forming.py'},
    {'id': 'dGwGJh', 'file_name': 'MG_Springback.py'},
    {'id': 'GZNYxh', 'file_name': 'PostProcessing.py'},
    {'id': 'bpDUxh', 'file_name': 'sedata.csv'}],
 'software_configurations': {'name': 'AI Can End',
  'test_mode': False,
  'run_job': True,
  'software': {'analysis': {'code': 'abaqus-dsls',
    'version': '2021-golden-DSLS'},
   'hardware': {'coresPerSlot': 4,
    'slots': 1,
    'coreType': 'starlite_max',
    'walltime': 3},
   'command': 'abaqus cae noGUI=MG_Forming.py; abaqus job=FormingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive parallel=domain double=both output_precision=full; abaqus cae noGUI=MG_Springback.py; abaqus job=SpringbackJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus cae noGUI=MG_Buckling.py; abaqus job=BucklingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus python PostProcessing.py',
   'output_file': 'PerfMetricsFile.csv',
   'envVars': {'DSLS_LICENSE_FILE': '4085@novelis'}}}}

# %%
########## step 3 ########
# select for short job
rescale_config = {'software_type': 'Abaqus',
 'analysis_type': 'AI Can End - Test - short',
 'files': [{'id': 'jfXNCh', 'file_name': 'abaqus_job.py'},
           {'id': 'GZNYxh', 'file_name': 'PostProcessing.py'}],
 'software_configurations': {'name': 'AI Can End',
  'test_mode': True,
  'run_job': False,
  'software': {'analysis': {'code': 'abaqus-dsls',
    'version': '2021-golden-DSLS'},
   'hardware': {'coresPerSlot': 4,
    'slots': 1,
    'coreType': 'starlite_max',
    'walltime': 3},
    'command': 'abaqus cae noGUI=abaqus_job.py; abaqus job=rescale_test.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi double=both interactive; abaqus python PostProcessing.py',
   'output_file': 'PerfMetricsFile.csv',
   'envVars': {'DSLS_LICENSE_FILE': '4085@novelis'}}}}

# %%
###### ABAQUS LONG
new_rescale = {
  "name": "Sample ABAQUS Simulation",
  "test_mode": False,
  "run_job": True,
  "batch_mode": True,  ### bydefault False
  "max_parallel_jobs": 2, ### bydefault len(trials) 
  # "input_variables": ['a', 'b'],
  # "output_variables":['c', 'd'],

  "files_detail":[
                  {"file_name": "PostProcessing.py", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/PostProcessing.py","upload_rescale": True, "rescale_id": "Vechjd"},
                  {"file_name": "MG_Buckling.py", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/MG_Buckling.py","upload_rescale": True, "rescale_id": "ftfYud"},
                  {"file_name": "MG_Forming.py", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/MG_Forming.py","upload_rescale": True, "rescale_id": "KeAfsd"},
                  {"file_name": "MG_Springback.py", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/MG_Springback.py","upload_rescale": True, "rescale_id": "tFKjsd"},
                  {"file_name": "sedata.csv", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/sedata.csv","upload_rescale": True, "rescale_id": "Sbetsd"},
                  {"file_name": "Visualizer.py", "file_path": "/Users/macbook/Documents/P1/Inputs/Rescale_widget/Visualizer.py","upload_rescale": True, "rescale_id": "AfuvLb"},
                  {"file_name": "custom_driver.py", "file_path": "/Users/macbook/Documents/custom_driver_data/AICED_PKL/HEXAIND_3.0/post_python/custom_driver.py","upload_rescale": False},
                  {"file_name": "scaler.pkl", "file_path": "/Users/macbook/Documents/custom_driver_data/AICED_PKL/HEXAIND_3.0/post_python/scaler.pkl","upload_rescale": False},
                  {"file_name": "gp_scaling.pkl", "file_path": "/Users/macbook/Documents/custom_driver_data/AICED_PKL/HEXAIND_3.0/post_python/gp_scaling.pkl","upload_rescale": False}
                  
                  ],
  "software": {
    "analysis": {
      "code": "abaqus-dsls",
      "version": "2023-golden-DSLS"
    },
    "hardware": {
      "walltime": 3,
      "coreType": "starlite_max",
      "slots": 1,
      "coresPerSlot": 4
    },
    "command": "abaqus cae noGUI=MG_Forming.py; abaqus job=FormingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive parallel=domain double=both output_precision=full; abaqus cae noGUI=MG_Springback.py; abaqus job=SpringbackJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus cae noGUI=MG_Buckling.py; abaqus job=BucklingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus python PostProcessing.py;abaqus cae noGUI=Visualizer.py",
    "reusable_job_file": "custom_driver.py,MG_Forming.py,MG_Springback.py,MG_Buckling.py,PostProcessing.py,Visualizer.py,scaler.pkl,gp_scaling.pkl,sedata.csv",
    "dynamic_job_file": "param_values.csv",
    "pre_python":None,
    "post_python":"custom_driver.py,scaler.pkl,gp_scaling.pkl",
    "output_file": "PerfMetricsFile.csv",
    "visualize_files": [
      "ShellGeometry.png",
      "ShellGeometry_Closeup.png",
      "FormingAnimation_Script.avi"
    ],
    "envVars": {
      "DSLS_LICENSE_FILE": "4085@novelis"
    }
  }
}
new_rescale.keys()

# %%
###### ABAQUS SHORT
new_rescale = {
  "name": "Sample ABAQUS Simulation",
  "test_mode": True,
  "run_job": False,
  "batch_mode": True,
  "max_parallel_jobs": 2,
  "files_detail":[{"file_name": "abaqus_job.py", "file_path": "/hexaind-data/hexaind-datasets/connection/65a517707518c363e4c0d3fb/abaqus_job.py","upload_rescale": True, "rescale_id": ""},
                  {"file_name": "PostProcessing.py", "file_path": "PostProcessing.py","upload_rescale": True, "rescale_id": "GZNYxh"},
                  # {"file_name": "custom_driver.py", "file_path": "/hexaind-data/hexaind-datasets/connection/65a517707518c363e4c0d3fb/123654789/custom_driver.py","upload_rescale": False},
                  # {"file_name": "scaler.pkl", "file_path": "/hexaind-data/hexaind-datasets/connection/65a517707518c363e4c0d3fb/123654789/scaler.pkl","upload_rescale": False},
                  # {"file_name": "gp_scaling.pkl", "file_path": "/hexaind-data/hexaind-datasets/connection/65a517707518c363e4c0d3fb/123654789/gp_scaling.pkl","upload_rescale": False}
                  
                  ],
  "software": {
    "analysis": {
      "code": "abaqus-dsls",
      "version": "2023-golden-DSLS"
    },
    "hardware": {
      "walltime": 3,
      "coreType": "starlite_max",
      "slots": 1,
      "coresPerSlot": 4
    },
    "command": "abaqus cae noGUI=MG_Forming.py; abaqus job=FormingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive parallel=domain double=both output_precision=full; abaqus cae noGUI=MG_Springback.py; abaqus job=SpringbackJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus cae noGUI=MG_Buckling.py; abaqus job=BucklingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus python PostProcessing.py;abaqus cae noGUI=Visualizer.py",
    "reusable_job_file": "custom_driver.py,MG_Forming.py,MG_Springback.py,MG_Buckling.py,PostProcessing.py,Visualizer.py,scaler.pkl,gp_scaling.pkl,sedata.csv",
    "dynamic_job_file": "param_values.csv",
    "pre_python":None,
    "post_python": None, #"post_python.py,scaler.pkl,gp_scaling.pkl",
    "output_file": "PerfMetricsFile.csv",
    "visualize_files": [
      "ShellGeometry.png",
      "ShellGeometry_Closeup.png",
      "FormingAnimation_Script.avi"
    ],
    "envVars": {
      "DSLS_LICENSE_FILE": "4085@novelis"
    }
  }
}
new_rescale.keys()

# %%
#### LS_DYNA LONG

false = False
true = True
null = None
new_rescale = {
  "name": "Sample LS-DYNA Simulation",
  "test_mode": false,
  "run_job": true,
  "files_detail":[
                  {"file_name": "custom_driver.py", "file_path": "/home/salman/Documents/custom_driver_data/AICED_PKL/HEXAIND_3.0/post_python/custom_driver.py","upload_rescale": False},
                  
                  
                  ],
  "apply_post_process": true,
  "software": {
    "analysis": {
      "code": "ls_dyna",
      "version": "12.0.0"
    },
    "command": "ls-dyna -i _ShellBuckle_V2.3.1.k -p single -s 1",
    "reusable_job_file": "custom_driver.py",
    "dynamic_job_file": "param_values.csv, _1883_XXXX.material, Blank.k, Tools.k, shellbuckleXXXX.k",
    "pre_python":"None",
    "post_python":"custom_driver.py",
    "hardware": {
      "walltime": 96,
      "coreType": "starlite_max",
      "slots": 1,
      "type": "compute",
      "coresPerSlot": 1
    },
    "envVars": {
      "LSTC_LICENSE_SERVER": "31010@novelis"
    },
    "onDemandLicenseSeller": null,
    "output_file": "abstat",
  }
}

# %%
#### LS_DYNA short

false = False
true = True
null = None
new_rescale = {
  "name": "Sample LS-DYNA Simulation",
  "test_mode": True,
  "run_job": False,
  "files_detail":[
                  {"file_name": "custom_driver.py", "file_path": "/home/salman/Documents/custom_driver_data/AICED_PKL/HEXAIND_3.0/post_python/custom_driver.py","upload_rescale": False},
                  
                  
                  ],
  "apply_post_process": true,
  "software": {
    "analysis": {
      "code": "ls_dyna",
      "version": "12.0.0"
    },
    "command": "ls-dyna -i _ShellBuckle_V2.3.1.k -p single -s 1",
    "reusable_job_file": "custom_driver.py",
    "dynamic_job_file": "param_values.csv, _1883_XXXX.material, Blank.k, Tools.k, shellbuckleXXXX.k",
    "pre_python":"None",
    "post_python":"custom_driver.py",
    "hardware": {
      "walltime": 96,
      "coreType": "starlite_max",
      "slots": 1,
      "type": "compute",
      "coresPerSlot": 1
    },
    "envVars": {
      "LSTC_LICENSE_SERVER": "31010@novelis"
    },
    "onDemandLicenseSeller": null,
    "output_file": "abstat",
  }
}

# %%
### step4 set rescale_connector_id according to your usecase 
gc_payload = {

'rescale_connector_id': '659d5ec5dc18e4cfbd266399', 
'rescale_configs':new_rescale,
'widget_type': 'RESCALE',
 
 }
gc_payload['rescale_configs']['software']['analysis']

# %%
true = True
false = False
null = None
abc = {
    "version": "1.0",
    "rescale_configs": {
        "name": "Sample ABAQUS Simulation",
        "test_mode": true,
        "run_job": false,
        "software": {
            "analysis": {
                "code": "abaqus-dsls",
                "version": "2021-golden-DSLS"
            },
            "hardware": {
                "walltime": 3,
                "coreType": "starlite_max",
                "slots": 1,
                "coresPerSlot": 4
            },
            "command": "abaqus cae noGUI=MG_Forming.py; abaqus job=FormingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive parallel=domain double=both output_precision=full; abaqus cae noGUI=MG_Springback.py; abaqus job=SpringbackJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus cae noGUI=MG_Buckling.py; abaqus job=BucklingJob.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi interactive double=both output_precision=full; abaqus python PostProcessing.py;abaqus cae noGUI=Visualizer.py",
            "reusable_job_file": "custom_driver.py,MG_Forming.py,MG_Springback.py,MG_Buckling.py,PostProcessing.py,Visualizer.py,scaler.pkl,gp_scaling.pkl,sedata.csv",
            "dynamic_job_file": "param_values.csv",
            "pre_python": null,
            "post_python": "post_python.py,scaler.pkl,gp_scaling.pkl",
            "output_file": "PerfMetricsFile.csv",
            "visualize_files": [
                "ShellGeometry.png",
                "ShellGeometry_Closeup.png",
                "FormingAnimation_Script.avi"
            ],
            "envVars": {
                "DSLS_LICENSE_FILE": "4085@novelis"
            }
        },
        "files_detail": [
            {
                "file_name": "custom_driver.py",
                "file_path": "\\tmp\\hexaind-datasets\\connection\\65e71f0d0e32acc5cc145d1a\\custom_driver.py",
                "upload_rescale": true,
                "rescale_id": ""
            },
            {
                "file_name": "MG_Forming.py",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": "",
                "success": "",
                "error": "Please upload the correct file"
            },
            {
                "file_name": "MG_Springback.py",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            },
            {
                "file_name": "MG_Buckling.py",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            },
            {
                "file_name": "PostProcessing.py",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            },
            {
                "file_name": "Visualizer.py",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            },
            {
                "file_name": "scaler.pkl",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            },
            {
                "file_name": "gp_scaling.pkl",
                "file_path": "",
                "upload_rescale": false,
                "rescale_id": ""
            }
        ]
    },
    "rescale_connector_id": "65e71f0d0e32acc5cc145d1a"
}

abc['rescale_configs']['software']['analysis']

# %%
import sys
sys.path.append('../../../../')
# from app.services.AI.rescale.schemas import RescaleConfig

# ## updating pydentic model
# config = RescaleConfig(**gc_payload)
# config

# %%
from app.services.AI.models.service import ModelService
from motor.motor_asyncio import AsyncIOMotorClient

# Database configuration
db_config = dict(
    db_address='0.0.0.0:27017',
    db_name="Hexaind",
    db_username="",
    db_password=""
)

# Creating an asynchronous client
client = AsyncIOMotorClient(
    db_config['db_address'],
    username=db_config['db_username'],
    password=db_config['db_password'],
    authSource=db_config['db_name']
)

# Access the database
db = client[db_config['db_name']]

model_obj = ModelService(db_async_client=client)
model_obj

# %%
await model_obj.delete_previous_runs_models(project_id='123', run_id='bdae322e-66cc-11ef-b316-acde48001122')
# Out:
# Deleting models for project_id: 123 and run_id: bdae322e-66cc-11ef-b316-acde48001122
# Deleted models for project_id: 123 and run_id: bdae322e-66cc-11ef-b316-acde48001122

# %% [markdown]
# BCED

# %%
from app.services.AI.rescale.service import RescaleService


### calling rescale functionality 

obj = RescaleService(db_sync_client=client)
kw_args = {
    'workflow_name': 'BCED_ABANDONED_TRIALS',
# 'mobo_output': 'tests/mobo_output.json',
# 'workflow_name': 'BCED_ABANDONED_TRIALS',  ##for BCED
# 'mobo_output': '/hexaind-data/hexaind-datasets/mobo_experiments/prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW/batch_21/mobo_output.csv' ##for BCED
# 'mobo_output': '/tmp/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh12356/batch_30/mobo_output.csv' ##for active learning
'mobo_output': '/hexaind-data/dataset/result/p_123/wf_123/r_789/batch_21/optimization_output.csv', ##update mobo_output value base on the mobo widget json path

}
aa = obj.run_rescale(config, **kw_args)

# %% [markdown]
# AICED

# %%
from app.services.AI.rescale.service import RescaleService
import os

### calling rescale functionality 

obj = RescaleService(db_sync_client=client)

results_folder = '/Users/macbook/hexaind-data/dataset/result/p_123/wf_456/r_789'

kw_args = {
    'workflow_name': 'AICED_CUST_AL_short',
# 'mobo_output': 'tests/mobo_output.json',
# 'workflow_name': 'BCED_ABANDONED_TRIALS',  ##for BCED
# 'mobo_output': '/hexaind-data/hexaind-datasets/mobo_experiments/prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW/batch_21/mobo_output.csv' ##for BCED
# 'mobo_output': '/tmp/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh12356/batch_30/mobo_output.csv' ##for active learning
'mobo_output': '/Users/macbook/hexaind-data/dataset/result/p_123/wf_456/r_789/batch_30/optimization_output.csv', ##update mobo_output value base on the mobo widget json path
'results_folder': results_folder,
'user_id': '66d1b341f6ad51422c3dd912'


}

os.makedirs(results_folder, exist_ok=True)
aa = obj.run_rescale(config, **kw_args)

# %%
import pandas as pd
pd.read_csv(aa.tabular_path)

# %%
aa

# %%
from app.services.AI.rescale.rescale_methods import create_trigger_rescale_job
import time
from threading import Thread


def process_job(job_data, sleep_time):
    print(f"Processing job {job_data['idx']}")
    time.sleep(sleep_time)
    print(f"Completed job {job_data['idx']}")
    job_data['trial_status'] = 'COMPLETED'  # Update the job status
    # job_queue.task_done()
    completed_jobs.append(job_data)

def create_job(next_observation: dict, trial_index: int) -> dict:
        rescale_files = eval(next_observation.get("rescale_files", '[]'))
        iter_csv_path = next_observation.get("iter_csv_path")

        kwargs = {"rescale_files": rescale_files, "rescale_config": config.rescale_configs}
        return create_trigger_rescale_job(
            'test_wf_name', trial_index, iter_csv_path, **kwargs
        )
        

sleep_time = 4
while not job_queue.empty():
    if in_progress_jobs < max_parallel_jobs:
        jd = job_queue.get()
        create_job(jd, jd['idx'])
        jd['trial_status'] = 'IN_PROGRESS'
        in_progress_jobs += 1  # Increment the in-progress job counter
        Thread(target=process_job, args=(jd, sleep_time)).start()
        # process_job(jd, sleep_time)
        sleep_time += 2
    elif job_queue.empty() and in_progress_jobs == 0:
        print('queue is empty')
        break  # Exit when all jobs are processed
    
    for jj in completed_jobs:
        if jj['trial_status'] == 'COMPLETED':
            in_progress_jobs -= 1
            # job_queue.task_done()

        else:
            print("jobs is in progress", jj['idx'])

# %%
short job workflow == '65eb232fb9f582c7c2d6a2aa'

long job workflow == '65eeec0eee71486da62fd764'

AL long job == '65f827fb0a7d03efd68ff203'

short al = '65f965cbd70e5c1311f4fa3c'

# %%
import requests
token = 'c4d23738ee9242a5f84417afa5740ab0d57257ce'
job_id = 'bNvSbc'
url = f'https://platform.rescale.com/api/v2/jobs/{job_id}/statuses/'
headers = {'Authorization': f'Token {token}'}

response = requests.get(url, headers=headers)
response

# %%
response.content

# %%
from bson import ObjectId
db.connectors.find_one({"_id": ObjectId('65a517707518c363e4c0d3fb')})

# %%
true = True
false = False
null = None
job_data = [
    {
        "job_id": "tDiqgb",
        "token": "9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5",
        "output_file_path": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_30/tDiqgb/PerfMetricsFile.csv",
        "trial_folder": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_30",
        "test_mode": true,
        "run_job": false,
        "visualize_files": [],
        "idx": "30",
        "parameters_file": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_30/param_values.csv",
        "visual_dir": null
    },
    {
        "job_id": "YQpDV",
        "token": "9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5",
        "output_file_path": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_31/YQpDV/PerfMetricsFile.csv",
        "trial_folder": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_31",
        "test_mode": true,
        "run_job": false,
        "visualize_files": [],
        "idx": "31",
        "parameters_file": "../post_rescale/tests/AICED_CUSTOM/batch_30/trial_31/param_values.csv",
        "visual_dir": null
    }
]

# %%
for jd in job_data:
    module_path = list(filter(lambda item: item.upload_rescale == False and item.file_name == 'post_python.py', config.rescale_configs.files_detail))[0].file_path
    custom_module = ModuleService(db_sync_client=client).import_module_from_path(module_path=str(module_path))
    kwargs = dict(rescale_output_file=Path(jd['output_file_path']), trial_folder=Path(jd['trial_folder']), parameters_file=Path(jd['parameters_file']), additional_files_dir=module_path.parent)
    jd['next_observation_evaluation'] = custom_module.PostProcess(**kwargs)
job_data

# %% [markdown]
# Ignore following

# %%
from rescale_methods import get_completed_job_rescale
aa = get_completed_job_rescale(token='9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5', job_id='SFyKq')
aa

# %%
aa

# %%
module_path = list(filter(lambda item: item['file_name'] == 'custom_driver.py', filesdetail))[0]['file_path']
module_path

# %%
import requests
res = requests.post(
  'https://platform.rescale.com/api/v2/jobs/uLFbe/force_stop/',
  headers={'Content-Type': 'application/json',
           'Authorization': 'Token 9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5'}
)
# res.json()

# %%
res.text

# %%
import requests

response = requests.get(
            f'https://platform.rescale.com/api/v2/jobs/bTXgV/statuses/',
            headers={'Authorization': f'Token 9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5'},
        )
response

# %%
results[0]

# %%
results = response.json()['results']
results

# %% [markdown]
# REAL JOB

# %%
import json

file_path ='/home/muhammad/Downloads/Databrick.connectors.json'
with open(file_path, 'r') as file:
    data = json.load(file)[0]

data

# %%
from bson.objectid import ObjectId
from datetime import datetime

data['_id'] = ObjectId(data['_id'])
data['created_at'] = datetime.now()
data['last_modified_at'] = data['created_at']
data

# %%
filt_soft = {key: value for key, value in data['configuration']['rescale_settings']['software']['hardware'].items() if value is not None}
data['configuration']['rescale_settings']['software']['hardware'] = filt_soft
data

# %%
db = client['Databrick']
db.connectors.delete_one({'_id': ObjectId('65a517707518c363e4c0d3fb')})
db.connectors.insert_one(data)

# %% [markdown]
# TEST JOB

# %%
connector_config = {
    "token": 'sdsfg',
    "rescale_settings": {
    "run_job": False,
    "test_mode": True,
    "name": "AI Can End - Test - short",
    "files": [{
                "id": "jfXNCh",
                "file_name": "abaqus_job.py"
            }],
    "software": {
                "software_type":"Abaqus",
                "envVars": {
                    "DSLS_LICENSE_FILE": "4085@novelis"
                },
                "output_file": "output.csv",
                "command": "abaqus cae noGUI=abaqus_job.py; abaqus job=rescale_test.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi double=both interactive; abaqus python post_process.py",
                "hardware": {
                    "coreType": "starlite_max",
                    "slots": 1,
                    "coresPerSlot": 4,
                    "walltime": 2
                },
                "analysis": {
                    "version": "2021-golden-DSLS",
                    "code": "abaqus-dsls"
                },
                # "visualize_files": []
                }

    
}}
connector_config

# %%
ac = RescaleConnectorConfiguration(**connector_config)

# %%
ac

# %%
ac.model_dump()

# %%
 {
        "created_at": "2023-11-29T10:53:10.725Z",
        "last_access": "2023-12-28T12:56:59.456Z",
        "custom_data": [],
        "custom_driver": False,
        "software_analysis": {
            "software": {
                "envVars": {
                    "DSLS_LICENSE_FILE": "4085@novelis"
                },
                "output_file": "output.csv",
                "command": "abaqus cae noGUI=abaqus_job.py; abaqus job=rescale_test.inp cpus=$RESCALE_CORES_PER_SLOT mp_mode=mpi double=both interactive; abaqus python post_process.py",
                "hardware": {
                    "coreType": "starlite_max",
                    "slots": 1,
                    "coresPerSlot": 4
                },
                "analysis": {
                    "version": "2021-golden-DSLS",
                    "code": "abaqus-dsls"
                }
            },
            "apply_post_process": True,
            "run_job": False,
            "test_mode": True,
            "name": "AI Can End - Test - short"
        },
        "selected_value": "AI Can End - Test - short",
        "is_updated": True,
        "files": [
            {
                "id": "jfXNCh",
                "name": "abaqus_job.py"
            },
            {
                "id": "Psdbsh",
                "name": "post_process.py"
            }
        ],
        "__v": 0,
        "software": "Abaqus",
        "is_uploaded": True,
        "token": "9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5",
        "created_by": "Databrick Tech",
        "user_id": "567a95c8ca676c1d07d5e3e7",
        "project_id": "6566fd41d9e1d100115962d7",
        "connectionName": "Rescale short job",
        "type": "Rescale",
        "_id": "65671816d9e1d100115962dd"
    }

# %%
from bson.objectid import ObjectId
from datetime import datetime
mongo_data = {
  "_id": ObjectId('659d5ec5dc18e4cfbd266390'),
  "id": "",
  "name": "azure-dev",
  "description": "Connector Description",
  "type": "RESCALE",
  "configuration": {
    "token": "9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5",
    "rescale_settings": ""
  },
  "owner_id": "",
  "owner_name": "",
  "created_at": datetime.now(),
  "last_modified_by_id": "",
  "last_modified_at": datetime.now(),
  "project_id": "1",
  "site_id": "1",
  "version": "1.0"
}

mongo_data
mongo_data['configuration'] = connector_config
mongo_data
db = client['Databrick']
# db.connectors.insert_one(mongo_data)

# %%
db.connectors.update_one({'_id': ObjectId('659d5ec5dc18e4cfbd266390')},
                        #  {"$set":{"configuration.token" : "9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5"}}
                         
                         {"$set":{"created_at" : mongo_data['created_at'],
                                  "last_modified_at" : mongo_data['created_at']}}

                         
                         )

# %%
for i in db.connectors.find({}):
    print(i)

# %%
from pydantic import BaseModel

# Define a Pydantic model
class User(BaseModel):
    id: int
    username: str
    email: str

class Male:
    def male_info(self, info: User):

# %%
# Create an instance of the model
user_data = {"id": 1, "username": "john_doe", "email": "john@example.com"}
user = User(**user_data)

# Access the model's attributes
print(user.id)       # Output: 1
print(user.username) # Output: john_doe
print(user.email)    # Output: john@example.com

# %%
from typing import Any, Mapping

from aiohttp import ClientSession
from fastapi import APIRouter, Response, status
from yarl import URL


RESCALE_URL = URL('https://platform.rescale.com/api/v2')
http_client_session: ClientSession = None

router = APIRouter()



from typing import Any, Optional

from pydantic import BaseModel


class Message(BaseModel):
    message: str
    data: Optional[Any] = None


class Authenticate(BaseModel):
    token: str


def authorization_header(api_token: str) -> Mapping[str, str]:
    return {'Authorization': f'Token {api_token}'}


def authenticate(auth_token: Authenticate) -> bool:
    with http_client_session.get(
        RESCALE_URL.join(URL('jobs')),
        headers=authorization_header(auth_token.token),
    ) as response:0
    return response.status != status.HTTP_401_UNAUTHORIZED



# @router.get('/authenticate')
# async def _authenticate(body: Authenticate, response: Response) -> Message:
#     try:
#         if await authenticate(body.token):
#             response.status_code = status.HTTP_200_OK
#             return Message(message='Authentication Successfull')
#         else:
#             response.status_code = status.HTTP_401_UNAUTHORIZED
#             return Message(message='Authentication Failed')
#     except Exception as e:
#         response.status_code = status.HTTP_500_INTERNAL_SERVER_ERROR
#         return Message(message=str(e))

# %%
Response

# %%
from typing import Any, Mapping
from yarl import URL
from pydantic import BaseModel
import requests


RESCALE_URL = URL('https://platform.rescale.com/api/v2')
http_client_session = requests.Session()  # Initializing Session


class Authenticate(BaseModel):
    token: str


def authorization_header(api_token: str) -> Mapping[str, str]:
    return {'Authorization': f'Token {api_token}'}


def authenticate(rescale_auth: Authenticate) -> bool:  # Define as async function
    with http_client_session.get(
        RESCALE_URL.join(URL('jobs')),
        headers=authorization_header(rescale_auth.token),
    ) as response:
        return response.status_code != 401
    

# async def rescale_authenticate(body: Authenticate, response: Response) -> Message:
#     try:
#         if await authenticate(body):
#             response.status_code = status.HTTP_200_OK
#             return Message(message='Authentication Successfull')
#         else:
#             response.status_code = status.HTTP_401_UNAUTHORIZED
#             return Message(message='Authentication Failed')
#     except Exception as e:
#         response.status_code = status.HTTP_500_INTERNAL_SERVER_ERROR
#         return Message(message=str(e))

# %%
ab = http_client_session.get( RESCALE_URL.join(URL('jobs')), headers=authorization_header('9460e4cdfcdbecf3aa9798564a50545b9ae9b2b55'))

# %%
ab.status_code

# %%
status.HTTP_401_UNAUTHORIZED

# %%
data = {'token': '9460e4cdfcdbecf3aa9798564a50545b9ae9b2b55'}
auth_data = Authenticate(**data)
auth_data

# %%
aa = authenticate(rescale_auth=auth_data)

# %% [markdown]
# NEW SCHEMA

# %%
rescale_payload = {'version': '0.1',
              'rescale_connector_id': 'asdsdfsgsd'
 }
rescale_payload

# %%
from pydantic import BaseModel, Field

from typing import Optional

class RescaleConfig(BaseModel):

    version: Optional[str] = Field(default="1.0", description="Rescale config version")

    rescale_connector_id: str = Field(..., description="Rescale connection id")

# %%
ad = RescaleConfig(**rescale_payload)
ad
