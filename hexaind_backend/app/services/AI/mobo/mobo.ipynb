# %% [markdown]
# BCED

# %%
import sys
sys.path.append('../../../../')
mobo_input_payload = {
 'input_variables': ['t_0', 't_1', 't_2', 't_3', 't_4', 't_5', 't_6', 't_7', 't_8', 't_9', 'r_1', 'r_2', 'r_3', 'r_4', 'r_5', 'r_6', 'r_7', 'r_8', 'r_9', 'r_10'],
 'input_variables_constraints': [[39.3579977835738, 51.574678234082], [9.77159156212368, 12.7728658971109], [-42.519509532725, -34.0215864556319], [36.3380364283033, 48.417423635541], [-3.72966234101399, 4.45735992697786], [-78.0230074912361, -69.52019768273695], [-85.7403171402542, -77.538919132725], [-4.28421664617977, 5.20129290577176], [29.8948322314041, 39.8778174510386], [-4.21569338159421, 3.69318699925818], [2.17654068477877, 2.89700712475637], [4.29190058640526, 5.71299484516714], [1.843764124993, 2.47265158452973], [173.305873972011, 223.217034153963], [0.241219153453138, 0.312236230733881], [0.569903621518138, 0.751732932431305], [26.1946339463934, 34.9127342836536], [0.510422015890195, 0.683696843422923], [70.3851180852223, 94.5768493483295], [0.464576798676445, 0.622901323722049]],
 'output_variables': ['buckle_pressure', 'Weight'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [11, 1],
 'num_iterations': 2,
 'run_iterations': True,
 'widget_type': 'MOBO',
 'experiment_type': 'OPTIMIZATION',
 'batch_size': 3,
 'constraints_module_id': '66c5a7ff6cce640f5da310b8',
#  'constraints_module_id': None,

 }


import os
results_folder = '/hexaind-data/dataset/result/p_123/wf_123/r_789'
kwargs = {'workflow_id': 'prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW',
 'workflow_name': 'BCED_ABANDONED_TRIALS',
 'project_id': '657849cebb20a16a3466db93',
 'training_data_path': 'tests/bced_v2_initial.csv',
  'initialize_experiment': True,
  'results_folder': results_folder,

}
os.makedirs(kwargs['results_folder'], exist_ok=True)

mobo_input_payload

# %% [markdown]
# AICED

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import FileDetails
mobo_input_payload = {
 'input_variables': ['dcp_spacer', 'pp_spacer', 'ips_pressure', 'up_pressure', 'friction_coeff', 'upper_radius', 'lower_radius', 't_value', 'lr_opening', 'catcher_depth', 'ips_radius', 'dcr_radius', 'dcp_radius_1', 'dcp_radius_2'],
 'input_variables_constraints': [[0.18, 0.18001799999999998], [0.144, 58], [61.75703273, 116.5307904], [60, 60.006], [0.05, 5], [0.005153495, 25], [0.005101214, 20.030728065], [0.010755824, 35.036], [1.679, 51.729843213], [0.085417634, 40.1], [0.029229092, 50.1], [0.060678336, 30.123677806], [0.027145029, 38.1], [0.02, 25.1]],
 'output_variables': ['buckle_pressure', 'max_thinning'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [111, 11],
 'num_iterations': 2,
 'run_iterations': True,
 'widget_type': 'MOBO',
#  'experiment_type': 'OPTIMIZATION',
 'experiment_type': 'ACTIVE_LEARNING',
 'batch_size': 1,
#  'constraints_module_id': '65eb2ecab9f582c7c2d6a2b5', #'65a164decbe8ff10ec0dcd55'
#  'constraints_module_id': None

 }
results_folder = '/Users/macbook/hexaind-data/dataset/result/p_123/wf_456/r_789'
kwargs = {'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123real',
 'workflow_name': 'AICED_CUST_AL_short',
 'project_id': '657849cebb20a16a3466db93',
 'training_data_path': 'tests/filtered_inputs_outputs_30.csv',
#  'training_data_path': '/home/muhammad/Downloads/all_inputs_some_outputs_30 (1).csv',

    'results_folder': results_folder,

  'initialize_experiment': True,
}
import os
os.makedirs(kwargs['results_folder'], exist_ok=True)
mobo_input_payload

# %% [markdown]
# Thermocalc

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import FileDetails
mobo_input_payload = {
 'input_variables': ['Si',
  'Fe',
  'Cu',
  'Mn',
  'Mg',
  'Cr',
  'Ti',
  'Zn',
  'Zr',
  'Sn',
  'V',
  'Ge',
  'HO_Step_1_Temp(C)',
  'HO_Step_1_Time(hr)',
  'HO_Step_2_Temp(C)',
  'HO_Step_2_Time(hr)',
  'HO_Step_3_Temp(C)',
  'HO_Step_3_Time(hr)',
  'HR_Lay_Down_Temp(C)',
  'HR_Transfer_Slab_Gauge_(IG)',
  'HB_gauge',
  'HR_Exit(C)',
  'pHR',
  'CR_Final_Gauge',
  'pCR',
  'CASH_PMT',
  'CASH_Dwell_time_Above_540(sec)',
  'PX_Temp(C)',
  'NA_Time(days)',
  'AA_Temperature(C)',
  'AA_Time(min)',
  'Prestrain'],
 'input_variables_constraints': [[0.61, 0.82],
  [0.23, 0.32],
  [0.09, 0.19],
  [0.07, 0.3],
  [0.63, 0.69],
  [0.01, 0.19],
  [0.01, 0.04],
  [0.01, 0.02],
  [0, 0.01],
  [0, 0.01],
  [0, 0.01],
  [0, 0.01],
  [530, 560],
  [6, 8],
  [0, 540],
  [0, 2],
  [0, 0.01],
  [0, 0.01],
  [515, 540],
  [40, 76],
  [5, 10],
  [330, 395],
  [0.87, 0.88],
  [0.9, 1],
  [0.81, 0.9],
  [578, 578.0578],
  [35, 45],
  [100, 110],
  [24, 37],
  [25, 25.0025],
  [80, 80.008],
  [0, 0.01]],
 'output_variables': ['Yield_Strength', 'Uniform_Elongation'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [55, 22],
 'num_iterations': 1,
 'run_iterations': True,
 'experiment_type': 'OPTIMIZATION',
 'widget_type': 'MOBO',
#  'experiment_type': 'ACTIVE_LEARNING',
 'batch_size': 2,
#  'constraints_module_id': '65eb2ecab9f582c7c2d6a2b5', #'65a164decbe8ff10ec0dcd55'
#  'constraints_module_id': None

 }
results_folder = '/hexaind-data/dataset/result/p_1234/wf_4567/r_789'

kwargs = {'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123567',
 'workflow_name': 'AICED_CUST_AL_short',
 'project_id': '657849cebb20a16a3466db93',
#  'training_data_path': 'tests/filtered_inputs_outputs_30.csv',
 'training_data_path': '/home/salman/Downloads/theromocalc_test.csv',
  'initialize_experiment': True,
    'results_folder': results_folder,
}
import os
os.makedirs(kwargs['results_folder'], exist_ok=True)
mobo_input_payload

# %% [markdown]
# Thermocalc All

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import FileDetails
mobo_input_payload = {
 'input_variables': [
                    "Si",
                    "Fe",
                    "Cu",
                    "Mn",
                    "Mg",
                    "Cr",
                    "Ti",
                    "Zn",
                    "Zr",
                    "Sn",
                    "V",
                    "Ge",
                    "HO_Step_1_Temp(C)",
                    "HO_Step_1_Time(hr)",
                    "HO_Step_2_Temp(C)",
                    "HO_Step_2_Time(hr)",
                    "HO_Step_3_Temp(C)",
                    "HO_Step_3_Time(hr)",
                    "HR_Lay_Down_Temp(C)",
                    "HR_Transfer_Slab_Gauge_(IG)",
                    "HB_gauge",
                    "HR_Exit(C)",
                    "pHR",
                    "CR_Final_Gauge",
                    "pCR",
                    "CASH_PMT",
                    "CASH_Dwell_time_Above_540(sec)",
                    "PX_Temp(C)",
                    "PX_time(hr)",
                    "NA_Time(days)",
                    "AA_Temperature(C)",
                    "AA_Time(min)",
                    "Prestrain",
                    "AL15SI2M4",
                    "DIAMOND_A4",
                    "FCC_A1",
                    "MG2SI_C1",
                    "AL9FE2SI2",
                    "Q_ALCUMGSI",
                    "Si_ss",
                    "Fe_ss",
                    "Cu_ss",
                    "Mn_ss",
                    "Mg_ss",
                    "pcpt_radius",
                    "pcpt_volfrac",
                    "solvus_temp",
                    "Si_pss",
                    "Fe_pss",
                    "Cu_pss",
                    "Mn_pss",
                    "Mg_pss",
                    "TE",
                    "UTS"
                ],
 'input_variables_constraints': [
                    [
                        0.33,
                        1.856
                    ],
                    [
                        0.09,
                        0.437
                    ],
                    [
                        0.028,
                        0.97
                    ],
                    [
                        0.03,
                        0.548
                    ],
                    [
                        0.356,
                        1.957
                    ],
                    [
                        0.009,
                        0.305
                    ],
                    [
                        0.0,
                        0.08
                    ],
                    [
                        0.0,
                        3.04
                    ],
                    [
                        0.0,
                        0.101
                    ],
                    [
                        0.0,
                        0.01
                    ],
                    [
                        0.0,
                        0.021
                    ],
                    [
                        0.0,
                        0.05
                    ],
                    [
                        500.0,
                        565.0
                    ],
                    [
                        2.0,
                        17.0
                    ],
                    [
                        0.0,
                        580.0
                    ],
                    [
                        0.0,
                        4.0
                    ],
                    [
                        0.0,
                        520.0
                    ],
                    [
                        0.0,
                        10.5
                    ],
                    [
                        430.0,
                        554.0
                    ],
                    [
                        33.0,
                        489.0
                    ],
                    [
                        4.84,
                        15.18
                    ],
                    [
                        205.0,
                        400.0
                    ],
                    [
                        0.75,
                        0.98
                    ],
                    [
                        0.9,
                        10.16
                    ],
                    [
                        0.0,
                        0.9
                    ],
                    [
                        520.0,
                        578.0
                    ],
                    [
                        0.0,
                        300.0
                    ],
                    [
                        25.0,
                        110.0
                    ],
                    [
                        0.0,
                        8.0
                    ],
                    [
                        3.0,
                        90.0
                    ],
                    [
                        25.0,
                        25.0025
                    ],
                    [
                        30.0,
                        80.0
                    ],
                    [
                        0.0,
                        0.0001
                    ],
                    [
                        1.27e-06,
                        0.01023372
                    ],
                    [
                        0.0,
                        0.010134355
                    ],
                    [
                        0.955616704,
                        0.983540811
                    ],
                    [
                        0.000877102,
                        0.011831987
                    ],
                    [
                        0.0,
                        0.008396935
                    ],
                    [
                        0.0,
                        0.004461655
                    ],
                    [
                        0.195744035,
                        1.326797207
                    ],
                    [
                        0.002454619,
                        0.02072924
                    ],
                    [
                        0.028710413,
                        0.980319132
                    ],
                    [
                        0.029773584,
                        0.214641192
                    ],
                    [
                        0.365032398,
                        1.992746734
                    ],
                    [
                        4.18e-10,
                        8.55e-10
                    ],
                    [
                        9.2e-10,
                        0.006420274
                    ],
                    [
                        182.2876793,
                        581.0698973
                    ],
                    [
                        0.195744005,
                        1.324321539
                    ],
                    [
                        0.002457912,
                        0.020729241
                    ],
                    [
                        0.028711832,
                        0.980781044
                    ],
                    [
                        0.029867313,
                        0.21464119
                    ],
                    [
                        0.362973346,
                        1.992714403
                    ],
                    [
                        20.4,
                        44.8
                    ],
                    [
                        182.0,
                        360.525
                    ]
                ],
                "output_variables": [
                    "Yield_Strength",
                    "Uniform_Elongation"
                ],
                "output_variables_objectives": [
                    "MAXIMUM",
                    "MAXIMUM"
                ],
                "output_variables_thresholds": [
                    150.0,
                    50.0
                ],
 'num_iterations': 2,
 'run_iterations': True,
 'experiment_type': 'OPTIMIZATION',
 'widget_type': 'MOBO',
#  'experiment_type': 'ACTIVE_LEARNING',
 'batch_size': 2,
#  'constraints_module_id': '65eb2ecab9f582c7c2d6a2b5', #'65a164decbe8ff10ec0dcd55'
#  'constraints_module_id': None

 }
results_folder = '/hexaind-data/dataset/result/p_12345/wf_4567/r_789'

kwargs = {'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123567',
 'workflow_name': 'AICED_CUST_AL_short',
 'project_id': '657849cebb20a16a3466db93',
#  'training_data_path': 'tests/filtered_inputs_outputs_30.csv',
 'training_data_path': '/home/salman/Downloads/vm1_p2_files/new_prediction_files/thermocalc_all_full_outputs_name.csv',
  'initialize_experiment': True,
    'results_folder': results_folder,
}
import os
os.makedirs(kwargs['results_folder'], exist_ok=True)
mobo_input_payload

# %%
from app.services.AI.mobo.schemas import MOBOConfig

mobo_config = MOBOConfig(**mobo_input_payload)

mobo_config

# %%
from app.services.AI.mobo.service import MOBOService
from pymongo import MongoClient
db_config = dict(db_address = '127.0.0.1' + ':27017', db_name = "Hexaind", db_username = "", db_password = "")
client = MongoClient(db_config['db_address'],
                        username=db_config['db_username'],
                        password=db_config['db_password'],
                        authSource=db_config['db_name'])

mobo = MOBOService(db_sync_client=client)

aa = mobo.run_mobo(mobo_config, **kwargs)

# %%
aa

# %%
import requests
response = requests.get(
            f'https://platform.rescale.com/api/v2/jobs/ognoo/statuses/',
            headers={'Authorization': f'Token 9460e4cdfcdbecf3aa9798564a50545b9ae9b2b5'},
        )
response.text

# %% [markdown]
# MOBO UPDATE EXPERIMENT

# %%
mobo_input_payload = {
 'input_variables': ['dcp_spacer', 'pp_spacer', 'ips_pressure', 'up_pressure', 'friction_coeff', 'upper_radius', 'lower_radius', 't_value', 'lr_opening', 'catcher_depth', 'ips_radius', 'dcr_radius', 'dcp_radius_1', 'dcp_radius_2'],
 'input_variables_constraints': [[0.18, 0.18001799999999998], [0.144, 58], [61.75703273, 116.5307904], [60, 60.006], [0.05, 5], [0.005153495, 25], [0.005101214, 20.030728065], [0.010755824, 35.036], [1.679, 51.729843213], [0.085417634, 40.1], [0.029229092, 50.1], [0.060678336, 30.123677806], [0.027145029, 38.1], [0.02, 25.1]],
 'output_variables': ['buckle_pressure', 'max_thinning'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [111, 11],
 'num_iterations': 2,
 'run_iterations': True,
#  'experiment_type': 'ACTIVE_LEARNING',
 'experiment_type': 'OPTIMIZATION',
 'widget_type': 'MOBO',
 'batch_size': 2,
 }
rescale_output = '/hexaind-data/dataset/result/p_123/wf_456/r_789/batch_32/rescale_output.csv' #'../post_rescale/tests/AICED_CUSTOM/batch_30/rescale_output.json'

thermocalc_output = None
mobo_input_payload

# %% [markdown]
# BCED

# %%
import sys
sys.path.append('../../../../')
mobo_input_payload = {
 'input_variables': ['t_0', 't_1', 't_2', 't_3', 't_4', 't_5', 't_6', 't_7', 't_8', 't_9', 'r_1', 'r_2', 'r_3', 'r_4', 'r_5', 'r_6', 'r_7', 'r_8', 'r_9', 'r_10'],
 'input_variables_constraints': [[39.3579977835738, 51.574678234082], [9.77159156212368, 12.7728658971109], [-42.519509532725, -34.0215864556319], [36.3380364283033, 48.417423635541], [-3.72966234101399, 4.45735992697786], [-75.0230074912361, -66.2097120787971], [-85.7403171402542, -77.538919132725], [-4.28421664617977, 5.20129290577176], [29.8948322314041, 39.8778174510386], [-4.21569338159421, 3.69318699925818], [2.17654068477877, 2.89700712475637], [4.29190058640526, 5.71299484516714], [1.843764124993, 2.47265158452973], [173.305873972011, 223.217034153963], [0.241219153453138, 0.312236230733881], [0.569903621518138, 0.751732932431305], [26.1946339463934, 34.9127342836536], [0.510422015890195, 0.683696843422923], [70.3851180852223, 94.5768493483295], [0.464576798676445, 0.622901323722049]],
 'output_variables': ['buckle_pressure', 'Weight'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [11, 1],
 'num_iterations': 2,
 'run_iterations': True,
 'widget_type': 'MOBO',
 'experiment_type': 'OPTIMIZATION',
 'batch_size': 3,
 'constraints_module_id': '66c5a7ff6cce640f5da310b8',
#  'constraints_module_id': None,

 }


import os
results_folder = '/hexaind-data/dataset/result/p_123/wf_123/r_789'
kwargs = {'workflow_id': 'prQPFCKBsYaFR0egiHGbiHvhEM5YBVfW',
 'workflow_name': 'BCED_ABANDONED_TRIALS',
 'project_id': '657849cebb20a16a3466db93',
#  'training_data_path': 'tests/bced_v2_initial.csv',
#   'initialize_experiment': True,
  'results_folder': results_folder,

}
os.makedirs(kwargs['results_folder'], exist_ok=True)
rescale_output = '/hexaind-data/dataset/result/p_123/wf_123/r_789/batch_25/rescale_output.csv' #'../post_rescale/tests/AICED_CUSTOM/batch_30/rescale_output.json'
thermocalc_output = None

mobo_input_payload

# %% [markdown]
# Thermocalc

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import FileDetails
mobo_input_payload = {
 'input_variables': ['Si',
  'Fe',
  'Cu',
  'Mn',
  'Mg',
  'Cr',
  'Ti',
  'Zn',
  'Zr',
  'Sn',
  'V',
  'Ge',
  'HO_Step_1_Temp(C)',
  'HO_Step_1_Time(hr)',
  'HO_Step_2_Temp(C)',
  'HO_Step_2_Time(hr)',
  'HO_Step_3_Temp(C)',
  'HO_Step_3_Time(hr)',
  'HR_Lay_Down_Temp(C)',
  'HR_Transfer_Slab_Gauge_(IG)',
  'HB_gauge',
  'HR_Exit(C)',
  'pHR',
  'CR_Final_Gauge',
  'pCR',
  'CASH_PMT',
  'CASH_Dwell_time_Above_540(sec)',
  'PX_Temp(C)',
  'NA_Time(days)',
  'AA_Temperature(C)',
  'AA_Time(min)',
  'Prestrain'],
 'input_variables_constraints': [[0.61, 0.82],
  [0.23, 0.32],
  [0.09, 0.19],
  [0.07, 0.3],
  [0.63, 0.69],
  [0.01, 0.19],
  [0.01, 0.04],
  [0.01, 0.02],
  [0, 0.01],
  [0, 0.01],
  [0, 0.01],
  [0, 0.01],
  [530, 560],
  [6, 8],
  [0, 540],
  [0, 2],
  [0, 0.01],
  [0, 0.01],
  [515, 540],
  [40, 76],
  [5, 10],
  [330, 395],
  [0.87, 0.88],
  [0.9, 1],
  [0.81, 0.9],
  [578, 578.0578],
  [35, 45],
  [100, 110],
  [24, 37],
  [25, 25.0025],
  [80, 80.008],
  [0, 0.01]],
 'output_variables': ['Yield_Strength', 'Uniform_Elongation'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [55, 22],
 'num_iterations': 2,
 'run_iterations': True,
 'widget_type': 'MOBO',
 'experiment_type': 'OPTIMIZATION',
#  'experiment_type': 'ACTIVE_LEARNING',
 'batch_size': 1,
#  'constraints_module_id': '65eb2ecab9f582c7c2d6a2b5', #'65a164decbe8ff10ec0dcd55'
#  'constraints_module_id': None

 }
results_folder = '/hexaind-data/dataset/result/p_1234/wf_4567/r_789'

kwargs = {'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123567',
 'workflow_name': 'AICED_CUST_AL_short',
 'project_id': '657849cebb20a16a3466db93',
#  'training_data_path': 'tests/filtered_inputs_outputs_30.csv',
    'results_folder' : results_folder,
}
thermocalc_output = "/hexaind-data/dataset/result/p_1234/wf_4567/r_789/batch_15/thermocalc_output.csv"

rescale_output = None
mobo_input_payload

# %% [markdown]
# Thermocalc All

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import FileDetails
mobo_input_payload = {
 'input_variables': [
                    "Si",
                    "Fe",
                    "Cu",
                    "Mn",
                    "Mg",
                    "Cr",
                    "Ti",
                    "Zn",
                    "Zr",
                    "Sn",
                    "V",
                    "Ge",
                    "HO_Step_1_Temp(C)",
                    "HO_Step_1_Time(hr)",
                    "HO_Step_2_Temp(C)",
                    "HO_Step_2_Time(hr)",
                    "HO_Step_3_Temp(C)",
                    "HO_Step_3_Time(hr)",
                    "HR_Lay_Down_Temp(C)",
                    "HR_Transfer_Slab_Gauge_(IG)",
                    "HB_gauge",
                    "HR_Exit(C)",
                    "pHR",
                    "CR_Final_Gauge",
                    "pCR",
                    "CASH_PMT",
                    "CASH_Dwell_time_Above_540(sec)",
                    "PX_Temp(C)",
                    "PX_time(hr)",
                    "NA_Time(days)",
                    "AA_Temperature(C)",
                    "AA_Time(min)",
                    "Prestrain",
                    "AL15SI2M4",
                    "DIAMOND_A4",
                    "FCC_A1",
                    "MG2SI_C1",
                    "AL9FE2SI2",
                    "Q_ALCUMGSI",
                    "Si_ss",
                    "Fe_ss",
                    "Cu_ss",
                    "Mn_ss",
                    "Mg_ss",
                    "pcpt_radius",
                    "pcpt_volfrac",
                    "solvus_temp",
                    "Si_pss",
                    "Fe_pss",
                    "Cu_pss",
                    "Mn_pss",
                    "Mg_pss",
                    "TE",
                    "UTS"
                ],
 'input_variables_constraints': [
                    [
                        0.33,
                        1.856
                    ],
                    [
                        0.09,
                        0.437
                    ],
                    [
                        0.028,
                        0.97
                    ],
                    [
                        0.03,
                        0.548
                    ],
                    [
                        0.356,
                        1.957
                    ],
                    [
                        0.009,
                        0.305
                    ],
                    [
                        0.0,
                        0.08
                    ],
                    [
                        0.0,
                        3.04
                    ],
                    [
                        0.0,
                        0.101
                    ],
                    [
                        0.0,
                        0.01
                    ],
                    [
                        0.0,
                        0.021
                    ],
                    [
                        0.0,
                        0.05
                    ],
                    [
                        500.0,
                        565.0
                    ],
                    [
                        2.0,
                        17.0
                    ],
                    [
                        0.0,
                        580.0
                    ],
                    [
                        0.0,
                        4.0
                    ],
                    [
                        0.0,
                        520.0
                    ],
                    [
                        0.0,
                        10.5
                    ],
                    [
                        430.0,
                        554.0
                    ],
                    [
                        33.0,
                        489.0
                    ],
                    [
                        4.84,
                        15.18
                    ],
                    [
                        205.0,
                        400.0
                    ],
                    [
                        0.75,
                        0.98
                    ],
                    [
                        0.9,
                        10.16
                    ],
                    [
                        0.0,
                        0.9
                    ],
                    [
                        520.0,
                        578.0
                    ],
                    [
                        0.0,
                        300.0
                    ],
                    [
                        25.0,
                        110.0
                    ],
                    [
                        0.0,
                        8.0
                    ],
                    [
                        3.0,
                        90.0
                    ],
                    [
                        25.0,
                        25.0025
                    ],
                    [
                        30.0,
                        80.0
                    ],
                    [
                        0.0,
                        0.0001
                    ],
                    [
                        1.27e-06,
                        0.01023372
                    ],
                    [
                        0.0,
                        0.010134355
                    ],
                    [
                        0.955616704,
                        0.983540811
                    ],
                    [
                        0.000877102,
                        0.011831987
                    ],
                    [
                        0.0,
                        0.008396935
                    ],
                    [
                        0.0,
                        0.004461655
                    ],
                    [
                        0.195744035,
                        1.326797207
                    ],
                    [
                        0.002454619,
                        0.02072924
                    ],
                    [
                        0.028710413,
                        0.980319132
                    ],
                    [
                        0.029773584,
                        0.214641192
                    ],
                    [
                        0.365032398,
                        1.992746734
                    ],
                    [
                        4.18e-10,
                        8.55e-10
                    ],
                    [
                        9.2e-10,
                        0.006420274
                    ],
                    [
                        182.2876793,
                        581.0698973
                    ],
                    [
                        0.195744005,
                        1.324321539
                    ],
                    [
                        0.002457912,
                        0.020729241
                    ],
                    [
                        0.028711832,
                        0.980781044
                    ],
                    [
                        0.029867313,
                        0.21464119
                    ],
                    [
                        0.362973346,
                        1.992714403
                    ],
                    [
                        20.4,
                        44.8
                    ],
                    [
                        182.0,
                        360.525
                    ]
                ],
                "output_variables": [
                    "Yield_Strength",
                    "Uniform_Elongation"
                ],
                "output_variables_objectives": [
                    "MAXIMUM",
                    "MAXIMUM"
                ],
                "output_variables_thresholds": [
                    150.0,
                    50.0
                ],
 'num_iterations': 2,
 'run_iterations': True,
 'experiment_type': 'OPTIMIZATION',
 'widget_type': 'MOBO',
#  'experiment_type': 'ACTIVE_LEARNING',
 'batch_size': 2,
#  'constraints_module_id': '65eb2ecab9f582c7c2d6a2b5', #'65a164decbe8ff10ec0dcd55'
#  'constraints_module_id': None

 }
results_folder = '/hexaind-data/dataset/result/p_12345/wf_4567/r_789'

kwargs = {'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123567',
 'workflow_name': 'AICED_CUST_AL_short',
 'project_id': '657849cebb20a16a3466db93',
#  'training_data_path': 'tests/filtered_inputs_outputs_30.csv',
#  'training_data_path': '/home/salman/Downloads/vm1_p2_files/new_prediction_files/T4_ALL_io.csv',
#   'initialize_experiment': True,
    'results_folder': results_folder,
}

thermocalc_output = "/hexaind-data/dataset/result/p_12345/wf_4567/r_789/batch_151/optimization_output.csv"

rescale_output = None

import os
os.makedirs(kwargs['results_folder'], exist_ok=True)
mobo_input_payload

# %%
import sys
sys.path.append('../../../../')
from app.services.AI.mobo.schemas import MOBOConfig

mobo_config = MOBOConfig(**mobo_input_payload)

mobo_config

# %%
from app.services.AI.mobo.service import MOBOService
from pymongo import MongoClient
db_config = dict(db_address = '0.0.0.0' + ':27017', db_name = "Hexaind", db_username = "", db_password = "")
client = MongoClient(db_config['db_address'],
                        username=db_config['db_username'],
                        password=db_config['db_password'],
                        authSource=db_config['db_name'])


mobo = MOBOService(db_sync_client=client)

# post_rescale_output =  None#'../post_rescale/tests/AICED_CUSTOM/batch_30/post_rescale_output.json'
# kwargs = {
#     'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123ADD',
#         #   'workflow_id': 'Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh12356', ##active learning
          
#           'workflow_name': 'AICED_CUST_AL_short',
# #  'workflow_name': 'AICED_CUST',
#  'project_id': '657849cebb20a16a3466db93',
# 'results_folder': results_folder,

# }
aa = mobo.update_mobo_experiment(mobo_config, rescale_output=rescale_output,thermocalc_output=thermocalc_output, **kwargs)

# %%
aa

# %%
evaluation_data = [{'Yield_Strength': (136.60783951711463, None), 'Ultimate_Tensile_Strength': (328.0195684399182, None), 'Uniform_Elongation': (23.290988344655933, None), 'Total_Elongation': (23.62356072647294, None), 'R-value': (0.6215978674376418, None), 'Beta_Bending': (109.80309472832977, None), 'IGC_Max': (275.1604897219696, None)}]
evaluation_data

# %%
import pandas as pd
# pp = '/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123567/batch_14/trial_14/qwwe/output.csv'
# pp = '/hexaind-data/hexaind-datasets/mobo_experiments/65f9f3c8eeb5a4f0d4667e78/batch_30/trial_30/param_values.csv'
df = pd.read_csv(rescale_output).to_dict('records')[0]
eval(df['next_observation_evaluation'])

# %%
def get_extra_thermocalc_variables_output(temp, input_vars=None, output_variables=None):
    in_out_cols = input_vars + output_variables
    for col in in_out_cols:
        if col in temp:
            del temp[col]

    return temp

# %%
get_extra_thermocalc_variables_output(df.copy(), mobo_config.input_variables, mobo_config.output_variables)

# %%
import pandas as pd
df = pd.read_csv('/hexaind-data/hexaind-datasets/mobo_experiments/65f2b44906fa8ee107a00646/batch_30/rescale_output.csv')
abc = df.to_dict('records')
eval(abc[0]['next_observation_evaluation'])

# %%
evaluation = {'buckle_pressure': [101.6778772187732, None], 'max_thinning': [9.30032620565519, None]}
{ ev : tuple(evaluation[ev]) for ev in evaluation }

# %%
import json
def load_json(json_file: str):
        with open(json_file, 'r') as file:
            return json.load(file)
        
rescale_output = '/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123/batch_30/rescale_output.json'
rescale_data = load_json(rescale_output)
rescale_data

# %%
def get_test_method(cols):
        # if 'dcpSpacerThickness' in cols or 'dcp_spacer' in cols:
        #     test_func = demos.can_fem
        # elif 'r' and 'h' in cols:
        #     test_func = demos.cone_areas
        # else:
        #     test_func = demos.bced_v2
        # return test_func
        return 1234

test_evaluation_method = None
next_observation_evaluation = []
for i in rescale_data:
    evaluation_data = dict() 
    if i['test_mode']:
        next_observation = pd.read_csv(i['parameters_file']).to_dict('records')[0]
        if not test_evaluation_method:
             test_evaluation_method = get_test_method(list(next_observation.keys()))
    else:
        if 'next_observation_evaluation' in i and i['next_observation_evaluation']:
             evaluation_data = i['next_observation_evaluation']
        else:
             pass
            
            
            # output_variables_aliases = {'bucklingPressure':'Buckling Pressure', 'maxThinning':'Max Thinning Percent'} #if headers in output csv are different than output_variables
            # # additional_rescale_data = get_extra_rescale_variables_output(i['output_file_path'], varibales_aliases=output_variables_aliases, output_variables=ax_obj.output_variables)
            # next_observation_evaluation = ax_obj.sort_rescale_trial_data(csv_path = job_data['output_file_path'], output_variables_aliases = output_variables_aliases)
            # try:
            #     #multiple maxThinning from rescale output by -1
            #     rev_thinning = next_observation_evaluation['maxThinning'][0]*-1
            #     next_observation_evaluation['maxThinning'] = (rev_thinning, None)
            # except:
            #     logger.error('Variable maxThinning not found in output.')
    next_observation_evaluation.append(test_evaluation_method(recommendation=next_observation))

# %%
def get_test_method(cols):
        # if 'dcpSpacerThickness' in cols or 'dcp_spacer' in cols:
        #     test_func = demos.can_fem
        # elif 'r' and 'h' in cols:
        #     test_func = demos.cone_areas
        # else:
        #     test_func = demos.bced_v2
        # return test_func
        return 1234
get_test_method

# %%
from pathlib import Path
# path = Path('/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123/batch_30/rescale_output.json')
path = Path('//hexaind-data//hexaind-datasets//mobo_experiments//Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123//batch_30//rescale_output.json')

with open(path, 'r', encoding='utf-8') as file:
    content = file.read()
content

# %%
import os
models_dir = os.path.dirname(__file__)

# %%
from app.services.AI.mobo.demo_optimization_api.models import *
import joblib
buckling_pressure_model = joblib.load("5b8f283e-5f8d-11ed-9317-00224829d8eerec_model.joblib")

# %%
rescale_data = None
import json
# aa = '/hexaind-data/hexaind-datasets/mobo_experiments/Xy3O7cE1x6iVFj6ukFzIVxjpmficWZh123/batch_30/rescale_output.json'
with open(mobo_input_payload['post_rescale_output'], 'r') as file:
    rescale_data = json.load(file)
rescale_data

# %%
 [{'buckle_pressure': (114.426217757049, None), 'max_thinning': (9.48652889226176, None)}, {'buckle_pressure': (114.42622584020249, None), 'max_thinning': (9.486526442843882, None)}]

# %%
for evl in range(len(rescale_data)):
    rescale_data[evl] = { i : tuple(rescale_data[evl][i]) for i in rescale_data[evl] }
rescale_data

# %%
for idx, i in enumerate(rescale_data):
    print(idx)

# %%
import pandas as pd
from demo_optimization_api import demos

def get_test_method(cols):
    if 'dcpSpacerThickness' in cols or 'dcp_spacer' in cols:
        test_func = demos.can_fem
    elif 'r' and 'h' in cols:
        test_func = demos.cone_areas
    else:
        test_func = demos.bced_v2
    return test_func

test_evaluation_method = None
for i in rescale_data:
    next_observation = pd.read_csv(i['parameters_file']).to_dict('records')[0]
    if not test_evaluation_method:
        test_evaluation_method = get_test_method(list(next_observation.keys()))
    next_observation_evaluation = test_evaluation_method(recommendation=next_observation)
    print(next_observation_evaluation)

# %%
next_observation

# %%
cols = {'dcp_spacer': 0.18, 'pp_spacer': 0.144, 'ips_pressure': 94.50111880239174, 'up_pressure': 60.0, 'friction_coeff': 0.05, 'upper_radius': 0.1123815685661192, 'lower_radius': 0.005101214, 't_value': 0.010755824, 'lr_opening': 1.679, 'catcher_depth': 0.0884122077863041, 'ips_radius': 0.6031956914195314, 'dcr_radius': 0.2060313072109438, 'dcp_radius_1': 0.2651860057874095, 'dcp_radius_2': 0.6961713695440761}

list(cols.keys())

# %%
cols = ['a', 'b', 'c', 'r', 'h']

'r' and 'h' in cols

# %% [markdown]
# NEW SCHEMA

# %%
mobo_input_payload = {
'version': '0.1',
 'input_variables': ['dcp_spacer', 'pp_spacer', 'ips_pressure', 'up_pressure', 'friction_coeff', 'upper_radius', 'lower_radius', 't_value', 'lr_opening', 'catcher_depth', 'ips_radius', 'dcr_radius', 'dcp_radius_1', 'dcp_radius_2'],
 'input_variables_constraints': [[0.18, 0.18001799999999998], [0.144, 58], [61.75703273, 116.5307904], [60, 60.006], [0.05, 5], [0.005153495, 25], [0.005101214, 20.030728065], [0.010755824, 35.036], [1.679, 51.729843213], [0.085417634, 40.1], [0.029229092, 50.1], [0.060678336, 30.123677806], [0.027145029, 38.1], [0.02, 25.1]],
 'output_variables': ['buckle_pressure', 'max_thinning'],
 'output_variables_objectives': ['MAXIMUM', 'MINIMUM'],
 'output_variables_thresholds': [111, 11],
 'num_iterations': 1,
 'initialize_experiment': True,
 'run_iterations': True,
 'batch_size': 2,
 'experiment_type': 'OPTIMIZATION',
'constraints_module_id': '',
'outcome_constraints_active': False,
'outcome_constraints_variables':[],
'outcome_constraints_operator': '',
'outcome_constaints_inputvalue': None
 }

# %%
from pydantic import BaseModel, Field

from enum import Enum

from typing import List, Optional

class MOBOExperimentType(str, Enum):

    OPTIMIZATION = "OPTIMIZATION"

    ACTIVE_LEARNING = "ACTIVE_LEARNING"

class MOBOExperimentOutputVariablesObjectives(str, Enum):

    MINIMUM = "MINIMUM"

    MAXIMUM = "MAXIMUM"

class MOBOConfig(BaseModel):

    version: Optional[str] = Field(default="1.0", description="Version of the workflow")

    experiment_type: MOBOExperimentType = Field(default=MOBOExperimentType.OPTIMIZATION, description="mobo algorithm type")

    input_variables: List[str] = Field(..., description="input features for mobo")

    input_variables_constraints: List[List[float]] = Field(..., description="filters on input features")

    output_variables: List[str] = Field(..., description="output features for mobo")

    output_variables_objectives: List[MOBOExperimentOutputVariablesObjectives] = Field(..., description="user defined mobo experiment name ")

    output_variables_thresholds: List[float] = Field(..., description="thresholds for the output features, this is more like boundary for recommendations")

    num_iterations: int = Field(..., description="number of times to run the experiment or target no.of batches")

    batch_size: int = Field(..., description="specifies no.of recommendations will be generated in one batch")

    constraints_module_id: Optional[str] = Field(default=None, description="module id for the user uploaded mobo recommendations validation scripts")

    outcome_constraints_active: Optional[bool] = Field(default=False, description="Outcome constraints tog ")

    outcome_constraints_variables: Optional[List[str]] = Field(default=[], description="user defined mobo experiment name ")

    outcome_constraints_operator: Optional[str] = Field(default=None, description="user defined mobo experiment name ")

    outcome_constaints_inputvalue: Optional[int] = Field(default=None, description="user defined mobo experiment name ")

# %%
ad = MOBOConfig(**mobo_input_payload)
ad

# %%
cc = ad.model_dump()

# %%
cc['experiment_type'] == 'OPTIMIZATION'

objective_min_bool = []
for i in cc['output_variables_objectives']:
    if i == 'MINIMUM':
        objective_min_bool.append(True)
    elif i == 'MAXIMUM':
        objective_min_bool.append(False)

    print(i)

objective_min_bool
